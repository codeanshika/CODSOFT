# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
creditdata=pd.read_csv('creditcard.csv')

# %%
creditdata.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
creditdata.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 146647  87799 -1.526981 -1.005619 -0.082273 -0.471613  1.801908 -0.739405
# 146648  87802 -0.282443  0.855224 -0.053295 -0.153733 -0.039449 -0.908046
# 146649  87802 -1.210583 -0.883923  0.085170 -0.082607  2.955753 -1.913757
# 146650  87802  2.074648 -0.031346 -1.119717  0.378411 -0.046723 -1.123364
# 146651  87802 -1.937944 -2.952790 -1.719233 -1.281131  1.905859 -1.217766
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 146647  1.286153 -0.574174  0.751797  ... -0.514188 -0.259192  1.262969
# 146648  0.377701  0.203070  0.126075  ...  0.187684  0.524025  0.020133
# 146649  0.104788 -0.242375  0.108291  ... -0.170043 -0.797627  0.260314
# 146650  0.198939 -0.340896  0.510285  ... -0.296367 -0.703354  0.319490
# 146651  1.343122 -0.894213 -0.834981  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 146647  0.228528 -0.542067  0.146979  0.109073 -0.329242   52.06    0.0
# 146648 -0.004336 -0.640167 -0.403877 -0.095465  0.030439   16.87    0.0
# 146649  0.526649 -0.015327 -0.670105 -0.170378 -0.110970    9.99    0.0
# 146650 -0.102920 -0.269098  0.204263 -0.068965 -0.061002    0.89    0.0
# 146651       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
creditdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146652 entries, 0 to 146651
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    146652 non-null  int64
#  1   V1      146652 non-null  float64
#  2   V2      146652 non-null  float64
#  3   V3      146652 non-null  float64
#  4   V4      146652 non-null  float64
#  5   V5      146652 non-null  float64
#  6   V6      146652 non-null  float64
#  7   V7      146652 non-null  float64
#  8   V8      146652 non-null  float64
#  9   V9      146652 non-null  float64
#  10  V10     146652 non-null  float64
#  11  V11     146652 non-null  float64
#  12  V12     146652 non-null  float64
#  13  V13     146652 non-null  float64
#  14  V14     146652 non-null  float64
#  15  V15     146651 non-null  float64
#  16  V16     146651 non-null  float64
#  17  V17     146651 non-null  float64
#  18  V18     146651 non-null  float64
#  19  V19     146651 non-null  float64
#  20  V20     146651 non-null  float64
#  21  V21     146651 non-null  float64
#  22  V22     146651 non-null  float64
#  23  V23     146651 non-null  float64
#  24  V24     146651 non-null  float64
#  25  V25     146651 non-null  float64
#  26  V26     146651 non-null  float64
#  27  V27     146651 non-null  float64
#  28  V28     146651 non-null  float64
#  29  Amount  146651 non-null  float64
#  30  Class   146651 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 34.7 MB

# %%
creditdata.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
creditdata['Class'].value_counts()
# Out:
# Class
# 0.0    146369
# 1.0       282
# Name: count, dtype: int64

# %%
positive=creditdata[creditdata.Class==0]
fraud=creditdata[creditdata.Class==1]

# %%
print(positive.shape)
print(fraud.shape)
# Out:
# (146369, 31)
# (282, 31)

# %%
positive.Amount.describe()
# Out:
# count    146369.000000
# mean         89.883061
# std         244.863711
# min           0.000000
# 25%           5.920000
# 50%          23.000000
# 75%          79.950000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     282.000000
# mean      119.469433
# std       242.629930
# min         0.000000
# 25%         1.000000
# 50%        10.685000
# 75%       105.695000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
creditdata.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    53398.296859 -0.241374  0.022925  0.669955  0.121833 -0.263292
# 1.0    45148.751773 -5.447576  3.843915 -7.029324  4.484769 -3.894992
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.077870 -0.101113  0.059996 -0.081467  ...  0.041969 -0.040677
# 1.0   -1.467947 -5.837845  1.498171 -2.639134  ...  0.279684  1.223495
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.116135 -0.031550  0.012499  0.127422  0.022135  0.000540  0.002445
# 1.0   -0.296468 -0.109456 -0.118201  0.209461  0.081154  0.524345  0.088142
#
#            Amount
# Class
# 0.0     89.883061
# 1.0    119.469433
#
# [2 rows x 30 columns]

# %%
positive_sample=positive.sample(n=492)

# %%
new_dataset=pd.concat([positive_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 110400  71811  1.603340 -1.157250  0.221101 -1.639799 -1.225506 -0.022784
# 91955   63706  0.711085 -1.066610  1.100089  0.501705 -1.471513 -0.145351
# 71374   54273  1.111803 -0.030977  0.460149  1.351597 -0.442141 -0.048261
# 11362   19812  1.229060 -0.255966  1.045040 -0.514545 -1.128524 -0.769656
# 55838   47150 -1.473705 -0.490746  1.251244 -1.383182 -0.179143 -1.012837
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 110400 -1.340557 -0.005841 -1.381712  ... -0.163665 -0.079068 -0.160781
# 91955  -0.415165  0.088650  1.108126  ... -0.037102 -0.296560 -0.018766
# 71374  -0.225552  0.278501  0.445559  ... -0.071126 -0.134822 -0.012926
# 11362  -0.637209 -0.128126  3.074451  ... -0.153918  0.038965 -0.035834
# 55838  -0.100164  0.093081 -0.331389  ...  0.085203  0.456418  0.007469
#
#              V24       V25       V26       V27       V28  Amount  Class
# 110400 -1.033627  0.502406 -0.013946  0.045605  0.010900    8.80    0.0
# 91955   0.697466 -0.080552  0.915573 -0.056126  0.054555  225.75    0.0
# 71374   0.154696  0.511192 -0.332466  0.018596  0.001143    4.99    0.0
# 11362   0.354585  0.479867 -0.727036  0.066187  0.031209   11.85    0.0
# 55838   0.393579  0.073193 -0.307049  0.298414  0.423304   38.94    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 143731  85576 -2.207631  3.259076 -5.436365  3.684737 -3.066401 -0.671323
# 144104  85864 -3.365265  2.928541 -5.660999  3.891160 -1.840375 -1.800887
# 144108  85867 -3.586964  2.609127 -5.568577  3.631947 -4.543590 -0.157899
# 144754  86376 -0.670238  0.945206  0.610051  2.640065 -2.707775  1.952611
# 145800  87202 -0.419820 -1.155978 -2.092516  2.786750  0.736297 -0.167292
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 143731 -3.696178  1.822272 -3.049653  ...  0.920899  0.037675  0.026754
# 144104 -5.558679  2.402322 -2.848923  ...  0.875260 -0.102501 -0.606283
# 144108 -4.089128  2.417305 -3.239901  ...  1.024423  0.428756  0.182032
# 144754 -1.624608 -5.229908  0.210202  ... -2.504450  1.436472  0.351542
# 145800  1.600027 -0.117427 -0.796954  ...  0.480640  0.533517  1.284645
#
#              V24       V25       V26       V27       V28  Amount  Class
# 143731 -0.791489  0.176493 -0.136312  1.087585  0.373834  240.77    1.0
# 144104 -0.743165  0.096319 -0.135060  1.238695  0.099824    1.00    1.0
# 144108 -0.534598  0.168933 -0.149844  0.685517 -0.299728  310.42    1.0
# 144754  0.648467  0.579681  0.075738  0.346717  0.282209  323.77    1.0
# 145800  0.516131 -0.602941 -0.305024 -0.021363  0.129096  451.27    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    282
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    53837.294715 -0.224826  0.033999  0.655614  0.076423 -0.320983
# 1.0    45148.751773 -5.447576  3.843915 -7.029324  4.484769 -3.894992
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.173612 -0.065591  0.116305 -0.110045  ...  0.089388 -0.072576
# 1.0   -1.467947 -5.837845  1.498171 -2.639134  ...  0.279684  1.223495
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.142893 -0.039584  0.047816  0.139970  0.012230  0.001790  0.003755
# 1.0   -0.296468 -0.109456 -0.118201  0.209461  0.081154  0.524345  0.088142
#
#            Amount
# Class
# 0.0    104.557602
# 1.0    119.469433
#
# [2 rows x 30 columns]

# %%
x=new_dataset.drop(columns='Class',axis=1)
y=new_dataset['Class']

# %%
print(x)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 110400  71811  1.603340 -1.157250  0.221101 -1.639799 -1.225506 -0.022784
# 91955   63706  0.711085 -1.066610  1.100089  0.501705 -1.471513 -0.145351
# 71374   54273  1.111803 -0.030977  0.460149  1.351597 -0.442141 -0.048261
# 11362   19812  1.229060 -0.255966  1.045040 -0.514545 -1.128524 -0.769656
# 55838   47150 -1.473705 -0.490746  1.251244 -1.383182 -0.179143 -1.012837
# ...       ...       ...       ...       ...       ...       ...       ...
# 143731  85576 -2.207631  3.259076 -5.436365  3.684737 -3.066401 -0.671323
# 144104  85864 -3.365265  2.928541 -5.660999  3.891160 -1.840375 -1.800887
# 144108  85867 -3.586964  2.609127 -5.568577  3.631947 -4.543590 -0.157899
# 144754  86376 -0.670238  0.945206  0.610051  2.640065 -2.707775  1.952611
# 145800  87202 -0.419820 -1.155978 -2.092516  2.786750  0.736297 -0.167292
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 110400 -1.340557 -0.005841 -1.381712  ... -0.330769 -0.163665 -0.079068
# 91955  -0.415165  0.088650  1.108126  ...  0.328623 -0.037102 -0.296560
# 71374  -0.225552  0.278501  0.445559  ... -0.374260 -0.071126 -0.134822
# 11362  -0.637209 -0.128126  3.074451  ... -0.133991 -0.153918  0.038965
# 55838  -0.100164  0.093081 -0.331389  ...  0.032997  0.085203  0.456418
# ...          ...       ...       ...  ...       ...       ...       ...
# 143731 -3.696178  1.822272 -3.049653  ...  0.808336  0.920899  0.037675
# 144104 -5.558679  2.402322 -2.848923  ...  0.576379  0.875260 -0.102501
# 144108 -4.089128  2.417305 -3.239901  ... -0.178534  1.024423  0.428756
# 144754 -1.624608 -5.229908  0.210202  ...  1.474929 -2.504450  1.436472
# 145800  1.600027 -0.117427 -0.796954  ...  1.275358  0.480640  0.533517
#
#              V23       V24       V25       V26       V27       V28  Amount
# 110400 -0.160781 -1.033627  0.502406 -0.013946  0.045605  0.010900    8.80
# 91955  -0.018766  0.697466 -0.080552  0.915573 -0.056126  0.054555  225.75
# 71374  -0.012926  0.154696  0.511192 -0.332466  0.018596  0.001143    4.99
# 11362  -0.035834  0.354585  0.479867 -0.727036  0.066187  0.031209   11.85
# 55838   0.007469  0.393579  0.073193 -0.307049  0.298414  0.423304   38.94
# ...          ...       ...       ...       ...       ...       ...     ...
# 143731  0.026754 -0.791489  0.176493 -0.136312  1.087585  0.373834  240.77
# 144104 -0.606283 -0.743165  0.096319 -0.135060  1.238695  0.099824    1.00
# 144108  0.182032 -0.534598  0.168933 -0.149844  0.685517 -0.299728  310.42
# 144754  0.351542  0.648467  0.579681  0.075738  0.346717  0.282209  323.77
# 145800  1.284645  0.516131 -0.602941 -0.305024 -0.021363  0.129096  451.27
#
# [774 rows x 30 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape ,x_train.shape,x_test.shape)
# Out:
# (774, 30) (619, 30) (155, 30)

# %%
model=LogisticRegression(max_iter=1000)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy=accuracy_score(y_train,x_train_prediction)

# %%
print('Accuracy score of test data:', training_data_accuracy)
# Out:
# Accuracy score of test data: 0.962843295638126

# %%
x_test_prediction=model.predict(x_test)
test_data_accuracy=accuracy_score(y_test,x_test_prediction)

# %%
print('Accuracy score of test data:', test_data_accuracy)
# Out:
# Accuracy score of test data: 0.9225806451612903
